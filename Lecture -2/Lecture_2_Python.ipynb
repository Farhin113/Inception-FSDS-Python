# %% [markdown]
# ## Conditional Statement

# %%
# Logic faction demo - Farhin.com

"""
Actual credentials;
email = sobnom900@gmail.com
password = sobnom23
"""
email = input("Enter the email: ")
password = input("Enter the password: ")

actual_email= "sobnom900@gmail.com"
actual_password="sobnom23"

if email == actual_email and password == actual_password:
    print("Successfull")

else:
    print("incorreat")
# Out:
# incorreat

# %%
# Logic faction demo - Farhin.com

"""
Actual credentials;
email = sobnom900@gmail.com
password = sobnom23
"""
email = input("Enter the email: ")
password = input("Enter the password: ")

actual_email= "sobnom900@gmail.com"
actual_password="sobnom23"

if email == actual_email and password == actual_password:
    print("Successfull")

elif  email == actual_email and password != actual_password:
    print("Try again")       

else:
    print("incorreat")
# Out:
# Successfull

# %% [markdown]
# ## Nested condition

# %%
# Logic faction demo - Farhin.com

"""
Actual credentials;
email = sobnom900@gmail.com
password = sobnom23
"""
email = input("Enter the email: ")
password = input("Enter the password: ")

actual_email= "sobnom900@gmail.com"
actual_password="sobnom23"

if email == actual_email and password == actual_password:
    print("Successfull")
   

elif  email == actual_email and password != actual_password:
    print("Plaese Try again")
    password = input("Enter the password again :") 

    if password == actual_password:
        print("Successfull") 

    else:
        print("It's incorreat")    


else:
    print("incorreat")
# Out:
# Plaese Try again
# Successfull

# %% [markdown]
# ## Modules in Python
# 1.Builtins modules / package
#
#
#
# 2.External modules / package

# %% [markdown]
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# ### 1.Builtins modules / package
# math
#
# keywords
#
# random
#
# datetime

# %%
import math

# %%
math.sqrt(200)
# Out:
# 14.142135623730951

# %%
math.factorial(5)
# Out:
# 120

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import random
print(random.randint(1,100))
# Out:
# 87

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-11-05 12:50:36.217693

# %% [markdown]
# ## External modules / package

# %%
# !pip install fastapi
