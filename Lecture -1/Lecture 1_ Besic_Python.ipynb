# %% [markdown]
# # Our Frist Python Program

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("My Name is Farhin Sobnom")
# Out:
# My Name is Farhin Sobnom

# %%
print(10)
# Out:
# 10

# %%
print(6.7)
# Out:
# 6.7

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print("Hello",1,2,3,4,5,True)
# Out:
# Hello 1 2 3 4 5 True

# %%
print("Hello",1,2,3,4,5,True, sep="-")
# Out:
# Hello-1-2-3-4-5-True

# %%
print("farhin",end="\n")
print("Sobnom")
# Out:
# farhin
# Sobnom

# %%
print("farhin",end=" ")
print("Sobnom")
# Out:
# farhin Sobnom

# %% [markdown]
# #Data Type In Python & Comment
# .Integer
# .Float
# .Boolean
# .String
# .Comlex
# .List
# .Tuple
# .Sets
# .Dictionary

# %%
# This is a single line Comment.this print function prints a sentence
print("My Name is Farhin Sobnom")
# Out:
# My Name is Farhin Sobnom

# %%
"""
This is a multiline comment.
we use it for multi line like a pragraph.
1....
2....
3...
"""
print("My Name is Farhin Sobnom")
# Out:
# My Name is Farhin Sobnom

# %%
#Integer number
print(56)
# Out:
# 56

# %%
type(56)
# Out:
# int

# %%
#Float number
print(4.3)
# Out:
# 4.3

# %%
type(4.3)
# Out:
# float

# %%
#Boolean
#Python is case sensative Language
print(True)
# Out:
# True

# %%
type(False)
# Out:
# bool

# %%
#String
print("Farhin Sobnom")
# Out:
# Farhin Sobnom

# %%
type("Farhin Sobnom")
# Out:
# str

# %%
#Complex number
print(3+2j)
# Out:
# (3+2j)

# %%
type(3+2j)
# Out:
# complex

# %%
#List
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
type([1,3,4,5,5])
# Out:
# list

# %%
#Tuple
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
type((1,2,3,4))
# Out:
# tuple

# %%
#sets
print({1,12,2})
# Out:
# {1, 2, 12}

# %%
type({1,12,1})
# Out:
# set

# %%
#Dictionary
print({"Name":"Farhin", "Age":20 })
# Out:
# {'Name': 'Farhin', 'Age': 20}

# %%
type({"Name":"Farhin","Age":20})
# Out:
# dict

# %% [markdown]
# #Variables, Keywords, & Indentifiers in Python

# %% [markdown]
# ##Variables

# %%
a = 2     #int
print(a)
# Out:
# 2

# %%
a = 5
b = 6
c = 3

print(a+b+c)
# Out:
# 14

# %%
#Dynamic Typing
a = 5

#Static Typing
int a = 5
# Out:
# int

# %%
a = 5
b = 7
c = 8
print(a,b,c)
# Out:
# 5 7 8

# %%
a = b = c = 7
print(a,b,c)
# Out:
# 7 7 7

# %% [markdown]
# #Keywords

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %% [markdown]
# #Identifiers

# %%
Name = "Farhin"
print(Name)
# Out:
# Farhin

# %%
# You can't start with any digit ;
1Name ="Sobnom"
# Out:
#   File "/tmp/ipython-input-4001917091.py", line 2
#     1Name ="Sobnom"
#     ^
# SyntaxError: invalid decimal literal

# %%
# You can't start with any special chars except_
Name$ = "ripa"
# Out:
#   File "/tmp/ipython-input-667566062.py", line 2
#     Name$ = "ripa"
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Python Input
#
# 1. Static- Calander,clock
# 2. Dainamic-You tube, Facebook

# %%
input()
# Out:
# 34
# '34'

# %%
var = input()
# Out:
# 56

# %%
print(var)
# Out:
# 56

# %%
type(var)
# Out:
# str

# %%
var = input("Inter your name :")
# Out:
# Inter your name :Farhin Sobnom

# %% [markdown]
# #Simple Calculator using input

# %%
a = input("Inter your first name :")
b = input("Inter your second name :")

print(a,b)
print(type(a))
print(type(b))
# Out:
# Inter your first name :8
# Inter your second name :5
# 8 5
# <class 'str'>
# <class 'str'>

# %%
a =int(input("Inter your first name :"))
b =int(input("Inter your second name :"))

print(a,b)
print(type(a))
print(type(b))
# Out:
# Inter your first name :5
# Inter your second name :7
# 5 7
# <class 'int'>
# <class 'int'>

# %%
a =int(input("Inter your first name :"))
b =int(input("Inter your second name :"))

Result = a + b
print(Result)
# Out:
# Inter your first name :4
# Inter your second name :8
# 12

# %% [markdown]
# #Type Conersion in Python
#
#
# 1.    Implicit-internally by python
# 2.  Explit-By the programmer

# %%
#Implicit
a = 5 + 5.5
print(a)
print(type(a))
# Out:
# 10.5
# <class 'float'>

# %%
#Explicit
a = 4 + int("4")
print(a)
print(type(a))
# Out:
# 8
# <class 'int'>

# %% [markdown]
# # Literals in Python

# %%
a = 4    #Int literals
print(type(a))
# Out:
# <class 'int'>

# %%
a = 0b1010 #Bi nary literals 
b = 100 #Dicimal literals
c = 0o310 # Octal literals
d = 0*12C # Hexadecimal literals

# %% [markdown]
# # float Literals

# %%
a = 10.5
b = 1.5e2 (1.5*10^2)
c = 1.5e-3(1.5*10^-3)

# %% [markdown]
# # Complex Literals

# %%
x = 3.13j

# %% [markdown]
# # Operator in Python
# 1, Arithmatic Operator
# 2, Relational Operator
# 3, Logical Operator
# 4, bitwise Operator
# 5, Assignment Operator
# 6, membership Operator

# %% [markdown]
# # Arithmatic Operator

# %%
print(5+7)
# Out:
# 12

# %%
print(8-5)
# Out:
# 3

# %% [markdown]
# # Relational Operator

# %%
print(6>5)
# Out:
# True

# %%
print(5<4)
# Out:
# False

# %%
print(5==5)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %% [markdown]
# # Logical Operator

# %%
print(0 and 1)
# Out:
# 0

# %%
print(0 or 1 )
# Out:
# 1

# %%
print(not 0)
# Out:
# True

# %% [markdown]
# # Bitwise Operator

# %%
&,|,<<,>>,-,^

# %% [markdown]
# # Assingment Operator

# %%
=,=+,-=,*=,%=

# %% [markdown]
# # Membership Operator

# %%
#in\not in

print("B"not in "Bangladsh")
# Out:
# False
